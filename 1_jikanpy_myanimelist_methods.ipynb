# %% [markdown]
# # Obtain reviews from MyAnimeList website through jikanpy API

# %%
from jikanpy import Jikan
import numpy as np
import pandas as pd
import time
import re

# %%
jikan = Jikan()

# %% [markdown]
# ### Helper method to scrape per anime (given its ID)

# %%
def get_anime_reviews_per_page(anime_id, last_page=1):
    assert(anime_id > 0)
    assert(last_page >= 1)

    reviews = []
    review_count = 0

    for page in range(1, last_page + 1):
        print("Getting page " + str(page) + " of " + str(last_page) + "...")

        anime_review = jikan.anime(id=anime_id, extension="reviews", page=page)["reviews"]
        review_count = review_count + len(anime_review)
        reviews.append(anime_review)

        time.sleep(4)

    return reviews, review_count

# %% [markdown]
# ### Helper method to convert the reviews into DataFrame

# %%
def convert_reviews_into_df(reviews):
    print("Converting reviews into df...")
    df = pd.DataFrame.from_dict(reviews[0])

    for review in reviews[1:]: 
        df = df.append(pd.DataFrame.from_dict(review))

    return df.reset_index(drop=True) # Prevents from inserting column "index"

# %% [markdown]
# ### Helper method to save a review to file

# %%
def save_to_file(df, filename, path="data/", to_csv=True, to_pickle=True):
    if to_csv:
        print("Saving " + str(len(df)) + " reviews into " + path + filename + ".csv...")
        df.to_csv(path + filename + ".csv")
    if to_pickle:
        print("Pickling " + str(len(df)) + " reviews into " + path + filename + ".pkl...")
        df.to_pickle(path + filename + ".pkl")

# %% [markdown]
# ### Creating DF of reviews per anime, saves to csv and/or pickle files

# %%
def scrape_and_save(anime_list, path="data/", to_csv=True, to_pickle=True):
    df_list = []
    
    for anime in anime_list:
        
        if anime["last"] > 0:
            print(anime["title"] + ", Season " + str(anime["season"]) + ":")

            reviews, count = get_anime_reviews_per_page(anime["id"], anime["last"])
            df = convert_reviews_into_df(reviews)
            df["Anime"] = anime["title"]
            df["Season"] = anime["season"]
            df["Done"] = anime["done"]

            filename = "-".join(re.sub(r"[^\w\d]+", " ", anime["title"].lower()).split())
            save_to_file(df, filename, path, to_csv, to_pickle)

            df_list.append({"id": anime["id"],
                            "df": df,
                            "title": anime["title"],
                            "filename": filename,
                            "count": count})

    return df_list

# %% [markdown]
# # ! ! ! Start editing here
# # Replace the anime list below depending on your assignment
#
#
#
# ### Declaring list of anime to scrape, where to save the produced df's, and in what format
# ### Make sure that the path you declare is an existing directory in your machine

# %%
# Replace the items in this list by using the format
anime_list = [
    {"id": 11061, "title": "Hunter x Hunter (2011)", "season": 1, "done": "Done", "last": 34 },
    {"id": 918, "title": "Gintama", "season": 1, "done": "Done", "last": 12 },
    {"id": 9969, "title": "Gintama'", "season": 2, "done": "Done", "last": 2 },
    {"id": 15417, "title": "Gintama': Enchousen", "season": 3, "done": "Done", "last": 1 },
    {"id": 28977, "title": "Gintama°", "season": 4, "done": "Done", "last": 3 },
    {"id": 34096, "title": "Gintama.", "season": 5, "done": "Done", "last": 2 },
    {"id": 121, "title": "Fullmetal Alchemist", "season": 1, "done": "Done", "last": 12 },
    {"id": 5114, "title": "Fullmetal Alchemist: Brotherhood", "season": 2, "done": "Done", "last": 40 },
    {"id": 31646, "title": "3-gatsu no Lion", "season": 1, "done": "Done", "last": 9 },
    {"id": 35180, "title": "3-gatsu no Lion 2nd Season", "season": 2, "done": "Done", "last": 6 },
    {"id": 2167, "title": "Clannad", "season": 1, "done": "Done", "last": 23 },
    {"id": 4181, "title": "Clannad: After Story", "season": 2, "done": "Done", "last": 33 },
    {"id": 32182, "title": "Mob Psycho 100", "season": 1, "done": "Done", "last": 10 },
    {"id": 37510, "title": "Mob Psycho 100 II", "season": 2, "done": "Done", "last": 9 },
    {"id": 45, "title": "Rurouni Kenshin: Meiji Kenkaku Romantan", "season": 1, "done": "Done", "last": 5 },
    {"id": 31181, "title": "Owarimonogatari", "season": 1, "done": "Done", "last": 2 },
    {"id": 35247, "title": "Owarimonogatari 2nd Season", "season": 2, "done": "Done", "last": 3 },
    {"id": 0, "title": "", "season": 1, "done": "Done", "last": 0 },
    {"id": 0, "title": "", "season": 1, "done": "Not Done", "last": 0 },
]

# Make sure to create this before running the next cell
path = "new-data/"
to_csv = False
to_pickle = True

# %%
df_list = scrape_and_save(anime_list, path, to_csv, to_pickle)
# Out:
# Hunter x Hunter (2011), Season 1:
# Getting page 1 of 34...
# Getting page 2 of 34...
# Getting page 3 of 34...
# Getting page 4 of 34...
# Getting page 5 of 34...
# Getting page 6 of 34...
# Getting page 7 of 34...
# Getting page 8 of 34...
# Getting page 9 of 34...
# Getting page 10 of 34...
# Getting page 11 of 34...
# Getting page 12 of 34...
# Getting page 13 of 34...
# Getting page 14 of 34...
# Getting page 15 of 34...
# Getting page 16 of 34...
# Getting page 17 of 34...
# Getting page 18 of 34...
# Getting page 19 of 34...
# Getting page 20 of 34...
# Getting page 21 of 34...
# Getting page 22 of 34...
# Getting page 23 of 34...
# Getting page 24 of 34...
# Getting page 25 of 34...
# Getting page 26 of 34...
# Getting page 27 of 34...
# Getting page 28 of 34...
# Getting page 29 of 34...
# Getting page 30 of 34...
# Getting page 31 of 34...
# Getting page 32 of 34...
# Getting page 33 of 34...
# Getting page 34 of 34...
# Converting reviews into df...
# Pickling 677 reviews into new-data/hunter-x-hunter-2011.pkl...
# Gintama, Season 1:
# Getting page 1 of 12...
# Getting page 2 of 12...
# Getting page 3 of 12...
# Getting page 4 of 12...
# Getting page 5 of 12...
# Getting page 6 of 12...
# Getting page 7 of 12...
# Getting page 8 of 12...
# Getting page 9 of 12...
# Getting page 10 of 12...
# Getting page 11 of 12...
# Getting page 12 of 12...
# Converting reviews into df...
# Pickling 229 reviews into new-data/gintama.pkl...
# Gintama', Season 2:
# Getting page 1 of 2...
# Getting page 2 of 2...
# Converting reviews into df...
# Pickling 30 reviews into new-data/gintama.pkl...
# Gintama': Enchousen, Season 3:
# Getting page 1 of 1...
# Converting reviews into df...
# Pickling 15 reviews into new-data/gintama-enchousen.pkl...
# Gintama°, Season 4:
# Getting page 1 of 3...
# Getting page 2 of 3...
# Getting page 3 of 3...
# Converting reviews into df...
# Pickling 53 reviews into new-data/gintama.pkl...
# Gintama., Season 5:
# Getting page 1 of 2...
# Getting page 2 of 2...
# Converting reviews into df...
# Pickling 23 reviews into new-data/gintama.pkl...
# Fullmetal Alchemist, Season 1:
# Getting page 1 of 12...
# Getting page 2 of 12...
# Getting page 3 of 12...
# Getting page 4 of 12...
# Getting page 5 of 12...
# Getting page 6 of 12...
# Getting page 7 of 12...
# Getting page 8 of 12...
# Getting page 9 of 12...
# Getting page 10 of 12...
# Getting page 11 of 12...
# Getting page 12 of 12...
# Converting reviews into df...
# Pickling 233 reviews into new-data/fullmetal-alchemist.pkl...
# Fullmetal Alchemist: Brotherhood, Season 2:
# Getting page 1 of 40...
# Getting page 2 of 40...
# Getting page 3 of 40...
# Getting page 4 of 40...
# Getting page 5 of 40...
# Getting page 6 of 40...
# Getting page 7 of 40...
# Getting page 8 of 40...
# Getting page 9 of 40...
# Getting page 10 of 40...
# Getting page 11 of 40...
# Getting page 12 of 40...
# Getting page 13 of 40...
# Getting page 14 of 40...
# Getting page 15 of 40...
# Getting page 16 of 40...
# Getting page 17 of 40...
# Getting page 18 of 40...
# Getting page 19 of 40...
# Getting page 20 of 40...
# Getting page 21 of 40...
# Getting page 22 of 40...
# Getting page 23 of 40...
# Getting page 24 of 40...
# Getting page 25 of 40...
# Getting page 26 of 40...
# Getting page 27 of 40...
# Getting page 28 of 40...
# Getting page 29 of 40...
# Getting page 30 of 40...
# Getting page 31 of 40...
# Getting page 32 of 40...
# Getting page 33 of 40...
# Getting page 34 of 40...
# Getting page 35 of 40...
# Getting page 36 of 40...
# Getting page 37 of 40...
# Getting page 38 of 40...
# Getting page 39 of 40...
# Getting page 40 of 40...
# Converting reviews into df...
# Pickling 789 reviews into new-data/fullmetal-alchemist-brotherhood.pkl...
# 3-gatsu no Lion, Season 1:
# Getting page 1 of 9...
# Getting page 2 of 9...
# Getting page 3 of 9...
# Getting page 4 of 9...
# Getting page 5 of 9...
# Getting page 6 of 9...
# Getting page 7 of 9...
# Getting page 8 of 9...
# Getting page 9 of 9...
# Converting reviews into df...
# Pickling 161 reviews into new-data/3-gatsu-no-lion.pkl...
# 3-gatsu no Lion 2nd Season, Season 2:
# Getting page 1 of 6...
# Getting page 2 of 6...
# Getting page 3 of 6...
# Getting page 4 of 6...
# Getting page 5 of 6...
# Getting page 6 of 6...
# Converting reviews into df...
# Pickling 103 reviews into new-data/3-gatsu-no-lion-2nd-season.pkl...
# Clannad, Season 1:
# Getting page 1 of 23...
# Getting page 2 of 23...
# Getting page 3 of 23...
# Getting page 4 of 23...
# Getting page 5 of 23...
# Getting page 6 of 23...
# Getting page 7 of 23...
# Getting page 8 of 23...
# Getting page 9 of 23...
# Getting page 10 of 23...
# Getting page 11 of 23...
# Getting page 12 of 23...
# Getting page 13 of 23...
# Getting page 14 of 23...
# Getting page 15 of 23...
# Getting page 16 of 23...
# Getting page 17 of 23...
# Getting page 18 of 23...
# Getting page 19 of 23...
# Getting page 20 of 23...
# Getting page 21 of 23...
# Getting page 22 of 23...
# Getting page 23 of 23...
# Converting reviews into df...
# Pickling 445 reviews into new-data/clannad.pkl...
# Clannad: After Story, Season 2:
# Getting page 1 of 33...
# Getting page 2 of 33...
# Getting page 3 of 33...
# Getting page 4 of 33...
# Getting page 5 of 33...
# Getting page 6 of 33...
# Getting page 7 of 33...
# Getting page 8 of 33...
# Getting page 9 of 33...
# Getting page 10 of 33...
# Getting page 11 of 33...
# Getting page 12 of 33...
# Getting page 13 of 33...
# Getting page 14 of 33...
# Getting page 15 of 33...
# Getting page 16 of 33...
# Getting page 17 of 33...
# Getting page 18 of 33...
# Getting page 19 of 33...
# Getting page 20 of 33...
# Getting page 21 of 33...
# Getting page 22 of 33...
# Getting page 23 of 33...
# Getting page 24 of 33...
# Getting page 25 of 33...
# Getting page 26 of 33...
# Getting page 27 of 33...
# Getting page 28 of 33...
# Getting page 29 of 33...
# Getting page 30 of 33...
# Getting page 31 of 33...
# Getting page 32 of 33...
# Getting page 33 of 33...
# Converting reviews into df...
# Pickling 642 reviews into new-data/clannad-after-story.pkl...
# Mob Psycho 100, Season 1:
# Getting page 1 of 10...
# Getting page 2 of 10...
# Getting page 3 of 10...
# Getting page 4 of 10...
# Getting page 5 of 10...
# Getting page 6 of 10...
# Getting page 7 of 10...
# Getting page 8 of 10...
# Getting page 9 of 10...
# Getting page 10 of 10...
# Converting reviews into df...
# Pickling 191 reviews into new-data/mob-psycho-100.pkl...
# Mob Psycho 100 II, Season 2:
# Getting page 1 of 9...
# Getting page 2 of 9...
# Getting page 3 of 9...
# Getting page 4 of 9...
# Getting page 5 of 9...
# Getting page 6 of 9...
# Getting page 7 of 9...
# Getting page 8 of 9...
# Getting page 9 of 9...
# Converting reviews into df...
# Pickling 163 reviews into new-data/mob-psycho-100-ii.pkl...
# Rurouni Kenshin: Meiji Kenkaku Romantan, Season 1:
# Getting page 1 of 5...
# Getting page 2 of 5...
# Getting page 3 of 5...
# Getting page 4 of 5...
# Getting page 5 of 5...
# Converting reviews into df...
# Pickling 92 reviews into new-data/rurouni-kenshin-meiji-kenkaku-romantan.pkl...
# Owarimonogatari, Season 1:
# Getting page 1 of 2...
# Getting page 2 of 2...
# Converting reviews into df...
# Pickling 25 reviews into new-data/owarimonogatari.pkl...
# Owarimonogatari 2nd Season, Season 2:
# Getting page 1 of 3...
# Getting page 2 of 3...
# Getting page 3 of 3...
# Converting reviews into df...
# Pickling 44 reviews into new-data/owarimonogatari-2nd-season.pkl...

# %%
len(df_list), len(anime_list)
# Out:
# (17, 19)

# %%
merged_df = df_list[0]["df"]

for df_to_append in df_list[1:]: 
    merged_df = merged_df.append(df_to_append["df"])

merged_df = merged_df.reset_index(drop="index")
merged_df
# Out:
#       mal_id                                            url  type  \
# 0     163333  https://myanimelist.net/reviews.php?id=163333  None
# 1     161751  https://myanimelist.net/reviews.php?id=161751  None
# 2     189776  https://myanimelist.net/reviews.php?id=189776  None
# 3     162739  https://myanimelist.net/reviews.php?id=162739  None
# 4     156637  https://myanimelist.net/reviews.php?id=156637  None
# ...      ...                                            ...   ...
# 3910  290795  https://myanimelist.net/reviews.php?id=290795  None
# 3911  274566  https://myanimelist.net/reviews.php?id=274566  None
# 3912  267112  https://myanimelist.net/reviews.php?id=267112  None
# 3913  371280  https://myanimelist.net/reviews.php?id=371280  None
# 3914  360022  https://myanimelist.net/reviews.php?id=360022  None
#
#       helpful_count                       date  \
# 0              2900  2014-10-02T17:27:00+00:00
# 1              1320  2014-09-23T12:33:00+00:00
# 2               917  2015-06-07T12:15:00+00:00
# 3               886  2014-09-28T10:56:00+00:00
# 4               505  2014-08-15T04:51:00+00:00
# ...             ...                        ...
# 3910              1  2018-10-03T09:57:00+00:00
# 3911              1  2018-03-22T11:32:00+00:00
# 3912              1  2018-01-01T12:50:00+00:00
# 3913              0  2021-01-02T14:18:00+00:00
# 3914              0  2020-10-13T10:15:00+00:00
#
#                                                reviewer  \
# 0     {'url': 'https://myanimelist.net/profile/Cresh...
# 1     {'url': 'https://myanimelist.net/profile/_juno...
# 2     {'url': 'https://myanimelist.net/profile/RedIn...
# 3     {'url': 'https://myanimelist.net/profile/Kyoum...
# 4     {'url': 'https://myanimelist.net/profile/DarkD...
# ...                                                 ...
# 3910  {'url': 'https://myanimelist.net/profile/Kiryu...
# 3911  {'url': 'https://myanimelist.net/profile/Valeo...
# 3912  {'url': 'https://myanimelist.net/profile/Umaig...
# 3913  {'url': 'https://myanimelist.net/profile/Mixal...
# 3914  {'url': 'https://myanimelist.net/profile/Racky...
#
#                                                 content  \
# 0     The lack of popularity surrounding Hunter x Hu...
# 1     ---The review contains spoilers---\r\n\r\n“You...
# 2     At first, when I read the synopsis of hunter x...
# 3     "I see now... Yes... I see... You had me in ch...
# 4     After reading the many overwhelmingly positive...
# ...                                                 ...
# 3910  I did not think that this story turned out to ...
# 3911  Such a great year for Anime!\r\n\r\nUnfortunat...
# 3912  The monogatari series is known for having an u...
# 3913  Finally, a conclusion to the adventure of arar...
# 3914  Owarimonogatari 2 is, for all intents and purp...
#
#                            Anime  Season  Done
# 0         Hunter x Hunter (2011)       1  Done
# 1         Hunter x Hunter (2011)       1  Done
# 2         Hunter x Hunter (2011)       1  Done
# 3         Hunter x Hunter (2011)       1  Done
# 4         Hunter x Hunter (2011)       1  Done
# ...                          ...     ...   ...
# 3910  Owarimonogatari 2nd Season       2  Done
# 3911  Owarimonogatari 2nd Season       2  Done
# 3912  Owarimonogatari 2nd Season       2  Done
# 3913  Owarimonogatari 2nd Season       2  Done
# 3914  Owarimonogatari 2nd Season       2  Done
#
# [3915 rows x 10 columns]

# %%
save_to_file(merged_df, filename="new-merged", path="new-data/", to_csv=False, to_pickle=True)
# Out:
# Pickling 3915 reviews into new-data/new-merged.pkl...

# %% [markdown]
# # Run the following code if you have an existing df_list already
# ### (e.g. you still have this notebook running but you decide to scrape additional anime)

# %%
new_anime_list = [
    {"id": 11061, "title": "Hunter x Hunter (2011)", "last": 34 }
]

path = "data/"
to_csv = True
to_pickle = True

# %%
new_df_list = scrape_and_save(new_anime_list, path, to_csv, to_pickle)
# Out:
# Hunter x Hunter (2011):
# Getting page 1 of 34...
# Getting page 2 of 34...
# Getting page 3 of 34...
# Getting page 4 of 34...
# Getting page 5 of 34...
# Getting page 6 of 34...
# Getting page 7 of 34...
# Getting page 8 of 34...
# Getting page 9 of 34...
# Getting page 10 of 34...
# Getting page 11 of 34...
# Getting page 12 of 34...
# Getting page 13 of 34...
# Getting page 14 of 34...
# Getting page 15 of 34...
# Getting page 16 of 34...
# Getting page 17 of 34...
# Getting page 18 of 34...
# Getting page 19 of 34...
# Getting page 20 of 34...
# Getting page 21 of 34...
# Getting page 22 of 34...
# Getting page 23 of 34...
# Getting page 24 of 34...
# Getting page 25 of 34...
# Getting page 26 of 34...
# Getting page 27 of 34...
# Getting page 28 of 34...
# Getting page 29 of 34...
# Getting page 30 of 34...
# Getting page 31 of 34...
# Getting page 32 of 34...
# Getting page 33 of 34...
# Getting page 34 of 34...
# Converting reviews into df...
# Saving 675 reviews into data/hunter-x-hunter-2011.csv...
# Pickling 675 reviews into data/hunter-x-hunter-2011.pkl...

# %%
df_list = df_list + new_df_list

# %%
len(df_list), len(new_anime_list)
# Out:
# (9, 1)

# %% [markdown]
# # Run the following code if you need to save the DF into a certain format again

# %%
for item in df_list:
    print(item["title"] + ":")
    save_to_file(item["df"], item["filename"], path, to_csv=True, to_pickle=True)
# Out:
# Durarara!!:
# Saving 350 reviews into data/durarara.csv...
# Pickling 350 reviews into data/durarara.pkl...
# Durarara!!x2 Ten:
# Saving 25 reviews into data/durarara-x2-ten.csv...
# Pickling 25 reviews into data/durarara-x2-ten.pkl...
# Durarara!!x2 Shou:
# Saving 35 reviews into data/durarara-x2-shou.csv...
# Pickling 35 reviews into data/durarara-x2-shou.pkl...
# Durarara!!x2 Ketsu:
# Saving 20 reviews into data/durarara-x2-ketsu.csv...
# Pickling 20 reviews into data/durarara-x2-ketsu.pkl...
# Boku no Hero Academia:
# Saving 363 reviews into data/boku-no-hero-academia.csv...
# Pickling 363 reviews into data/boku-no-hero-academia.pkl...
# Boku no Hero Academia 2nd Season:
# Saving 148 reviews into data/boku-no-hero-academia-2nd-season.csv...
# Pickling 148 reviews into data/boku-no-hero-academia-2nd-season.pkl...
# Boku no Hero Academia 3rd Season:
# Saving 112 reviews into data/boku-no-hero-academia-3rd-season.csv...
# Pickling 112 reviews into data/boku-no-hero-academia-3rd-season.pkl...
# Boku no Hero Academia 4th Season:
# Saving 144 reviews into data/boku-no-hero-academia-4th-season.csv...
# Pickling 144 reviews into data/boku-no-hero-academia-4th-season.pkl...
# Hunter x Hunter (2011):
# Saving 675 reviews into data/hunter-x-hunter-2011.csv...
# Pickling 675 reviews into data/hunter-x-hunter-2011.pkl...

# %%
csv_df = pd.read_csv("data/" + df_list[0]["filename"] + ".csv", encoding="utf-8", index_col=0)
csv_df
# Out:
#      mal_id                                            url  type  \
# 0     27162   https://myanimelist.net/reviews.php?id=27162   NaN
# 1     34917   https://myanimelist.net/reviews.php?id=34917   NaN
# 2    171215  https://myanimelist.net/reviews.php?id=171215   NaN
# 3     36712   https://myanimelist.net/reviews.php?id=36712   NaN
# 4     27619   https://myanimelist.net/reviews.php?id=27619   NaN
# ..      ...                                            ...   ...
# 345  110315  https://myanimelist.net/reviews.php?id=110315   NaN
# 346  373325  https://myanimelist.net/reviews.php?id=373325   NaN
# 347  131081  https://myanimelist.net/reviews.php?id=131081   NaN
# 348  125147  https://myanimelist.net/reviews.php?id=125147   NaN
# 349  205768  https://myanimelist.net/reviews.php?id=205768   NaN
#
#      helpful_count                       date  \
# 0             1164  2010-06-14T22:19:00+00:00
# 1              454  2011-03-05T18:00:00+00:00
# 2              366  2014-12-06T09:36:00+00:00
# 3              278  2011-05-03T10:24:00+00:00
# 4              182  2010-06-26T05:41:00+00:00
# ..             ...                        ...
# 345              0  2013-08-19T00:42:00+00:00
# 346              0  2021-01-13T16:52:00+00:00
# 347              0  2014-02-01T20:48:00+00:00
# 348              0  2013-12-22T22:52:00+00:00
# 349              0  2015-12-17T07:51:00+00:00
#
#                                               reviewer  \
# 0    {'url': 'https://myanimelist.net/profile/Alayn...
# 1    {'url': 'https://myanimelist.net/profile/daimi...
# 2    {'url': 'https://myanimelist.net/profile/Aerel...
# 3    {'url': 'https://myanimelist.net/profile/Andri...
# 4    {'url': 'https://myanimelist.net/profile/Lindl...
# ..                                                 ...
# 345  {'url': 'https://myanimelist.net/profile/Jerbe...
# 346  {'url': 'https://myanimelist.net/profile/kakeg...
# 347  {'url': 'https://myanimelist.net/profile/boyso...
# 348  {'url': 'https://myanimelist.net/profile/lambo...
# 349  {'url': 'https://myanimelist.net/profile/Natch...
#
#                                                content
# 0    This anime is... for lack of a better term, th...
# 1    I finally finished "Durarara!!" and while ther...
# 2    TL;DR watch Baccano instead\r\n\r\nDurarara li...
# 3    The world of anime never ceases to come up wit...
# 4    From the very get-go, even from the opening ti...
# ..                                                 ...
# 345  This anime may seem slow at first, but it take...
# 346  This anime is confusing I'm telling you. Liter...
# 347  I'm usually not that good when it comes to wri...
# 348  Before going into Durarara, i honestly didn't ...
# 349  For those of you who haven't seen this show ye...
#
# [350 rows x 7 columns]

# %%
pkl_df = pd.read_pickle("data/" + df_list[0]["filename"] + ".pkl")
pkl_df
# Out:
#      mal_id                                            url  type  \
# 0     27162   https://myanimelist.net/reviews.php?id=27162  None
# 1     34917   https://myanimelist.net/reviews.php?id=34917  None
# 2    171215  https://myanimelist.net/reviews.php?id=171215  None
# 3     36712   https://myanimelist.net/reviews.php?id=36712  None
# 4     27619   https://myanimelist.net/reviews.php?id=27619  None
# ..      ...                                            ...   ...
# 345  110315  https://myanimelist.net/reviews.php?id=110315  None
# 346  373325  https://myanimelist.net/reviews.php?id=373325  None
# 347  131081  https://myanimelist.net/reviews.php?id=131081  None
# 348  125147  https://myanimelist.net/reviews.php?id=125147  None
# 349  205768  https://myanimelist.net/reviews.php?id=205768  None
#
#      helpful_count                       date  \
# 0             1164  2010-06-14T22:19:00+00:00
# 1              454  2011-03-05T18:00:00+00:00
# 2              366  2014-12-06T09:36:00+00:00
# 3              278  2011-05-03T10:24:00+00:00
# 4              182  2010-06-26T05:41:00+00:00
# ..             ...                        ...
# 345              0  2013-08-19T00:42:00+00:00
# 346              0  2021-01-13T16:52:00+00:00
# 347              0  2014-02-01T20:48:00+00:00
# 348              0  2013-12-22T22:52:00+00:00
# 349              0  2015-12-17T07:51:00+00:00
#
#                                               reviewer  \
# 0    {'url': 'https://myanimelist.net/profile/Alayn...
# 1    {'url': 'https://myanimelist.net/profile/daimi...
# 2    {'url': 'https://myanimelist.net/profile/Aerel...
# 3    {'url': 'https://myanimelist.net/profile/Andri...
# 4    {'url': 'https://myanimelist.net/profile/Lindl...
# ..                                                 ...
# 345  {'url': 'https://myanimelist.net/profile/Jerbe...
# 346  {'url': 'https://myanimelist.net/profile/kakeg...
# 347  {'url': 'https://myanimelist.net/profile/boyso...
# 348  {'url': 'https://myanimelist.net/profile/lambo...
# 349  {'url': 'https://myanimelist.net/profile/Natch...
#
#                                                content
# 0    This anime is... for lack of a better term, th...
# 1    I finally finished "Durarara!!" and while ther...
# 2    TL;DR watch Baccano instead\r\n\r\nDurarara li...
# 3    The world of anime never ceases to come up wit...
# 4    From the very get-go, even from the opening ti...
# ..                                                 ...
# 345  This anime may seem slow at first, but it take...
# 346  This anime is confusing I'm telling you. Liter...
# 347  I'm usually not that good when it comes to wri...
# 348  Before going into Durarara, i honestly didn't ...
# 349  For those of you who haven't seen this show ye...
#
# [350 rows x 7 columns]
